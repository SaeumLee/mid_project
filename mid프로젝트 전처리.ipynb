# %% [markdown]
# # 신혼부부 총괄 데이터 전처리

# %%
import pandas as pd

# %%
datas = pd.read_csv('/content/drive/MyDrive/5. 미드프로젝트/시도별_신혼부부_총괄_20240317232708.csv' ,encoding = 'cp949')
datas.head(5)
# Out:
#            항목  행정구역별       2015       2016       2017       2018       2019  \
# 0  신혼부부 수 (A)     전국  1471647.0  1436948.0  1379766.0  1322406.0  1260117.0
# 1  신혼부부 수 (A)  서울특별시   291341.0   278294.0   263148.0   246867.0   232454.0
# 2  신혼부부 수 (A)  부산광역시    90578.0    88339.0    83545.0    77755.0    72403.0
# 3  신혼부부 수 (A)  대구광역시    62811.0    61356.0    59102.0    56985.0    54078.0
# 4  신혼부부 수 (A)  인천광역시    89747.0    87898.0    83619.0    80023.0    75794.0
#
#         2020       2021       2022
# 0  1183750.0  1101455.0  1032253.0
# 1   219101.0   200477.0   184084.0
# 2    67632.0    62431.0    58215.0
# 3    49774.0    45094.0    41617.0
# 4    69296.0    65347.0    62844.0

# %%
datas.shape
# Out:
# (144, 10)

# %%
# 시계열 항목의 컬럼을 행으로 밀어넣고 아래에 파이썬을 사용하여 아래의 datas1처럼 만들기

datas2 = datas.melt(id_vars=['항목', '행정구역별'], var_name='연도', value_name='데이터')
datas2
# Out:
#               항목    행정구역별    연도         데이터
# 0     신혼부부 수 (A)       전국  2015  1471647.00
# 1     신혼부부 수 (A)    서울특별시  2015   291341.00
# 2     신혼부부 수 (A)    부산광역시  2015    90578.00
# 3     신혼부부 수 (A)    대구광역시  2015    62811.00
# 4     신혼부부 수 (A)    인천광역시  2015    89747.00
# ...          ...      ...   ...         ...
# 1147    평균 출생아 수     전라북도  2022        0.95
# 1148    평균 출생아 수     전라남도  2022        1.01
# 1149    평균 출생아 수     경상북도  2022        0.90
# 1150    평균 출생아 수     경상남도  2022        0.88
# 1151    평균 출생아 수  제주특별자치도  2022        0.89
#
# [1152 rows x 4 columns]

# %%
datas1 = pd.read_csv('/content/drive/MyDrive/5. 미드프로젝트/시도별_신혼부부_총괄.csv', encoding='cp949')
datas1
# Out:
#         행정구역별    시점                          항목         데이터
# 0          전국  2015                  신혼부부 수 (A)  1471647.00
# 1          전국  2015                맞벌이 부부 수 (B)   595850.00
# 2          전국  2015            맞벌이 비율 (B/A*100)       40.50
# 3          전국  2015             주택소유 신혼부부 수 (C)   640709.00
# 4          전국  2015            주택 소유율 (C/A*100)       43.50
# ...       ...   ...                         ...         ...
# 1147  제주특별자치도  2022             주택소유 신혼부부 수 (C)     6957.00
# 1148  제주특별자치도  2022            주택 소유율 (C/A*100)       46.60
# 1149  제주특별자치도  2022             총 소유 주택 수 (D)\t     9192.00
# 1150  제주특별자치도  2022  소유부부기준 1쌍당 평균 소유주택 수 (D/C)        1.30
# 1151  제주특별자치도  2022                    평균 출생아 수        0.89
#
# [1152 rows x 4 columns]

# %% [markdown]
# # 맞벌이 여부별 신혼부부수 전처리

# %%
df = pd.read_csv('/content/drive/MyDrive/5. 미드프로젝트/맞벌이여부별신혼부부수_csv.csv', encoding='cp949')
df
# Out:
#         시점 신혼부부 특성별(1) 신혼부부 특성별(2) 맞벌이여부별(1) 맞벌이여부별(2)        데이터
# 0     2015          전국          소계        합계        소계  1,471,647
# 1     2015          전국          소계       맞벌이        소계    595,850
# 2     2015          전국          소계       외벌이        소계    735,503
# 3     2015          전국          소계       외벌이       남편만    635,596
# 4     2015          전국          소계       외벌이       아내만     99,907
# ...    ...         ...         ...       ...       ...        ...
# 1963  2022    주택소유물건수별        3건이상       맞벌이        소계      8,345
# 1964  2022    주택소유물건수별        3건이상       외벌이        소계      5,180
# 1965  2022    주택소유물건수별        3건이상       외벌이       남편만      4,056
# 1966  2022    주택소유물건수별        3건이상       외벌이       아내만      1,124
# 1967  2022    주택소유물건수별        3건이상        기타        소계        884
#
# [1968 rows x 6 columns]

# %%
# 신혼부부 특성별(1) 특성별에서 전국만 뽑아서 저장.
df1 = df.loc[df["신혼부부 특성별(1)"] == '전국', :]
df1
# Out:
#         시점 신혼부부 특성별(1) 신혼부부 특성별(2) 맞벌이여부별(1) 맞벌이여부별(2)        데이터
# 0     2015          전국          소계        합계        소계  1,471,647
# 1     2015          전국          소계       맞벌이        소계    595,850
# 2     2015          전국          소계       외벌이        소계    735,503
# 3     2015          전국          소계       외벌이       남편만    635,596
# 4     2015          전국          소계       외벌이       아내만     99,907
# 5     2015          전국          소계        기타        소계    140,294
# 246   2016          전국          소계        합계        소계  1,436,948
# 247   2016          전국          소계       맞벌이        소계    603,281
# 248   2016          전국          소계       외벌이        소계    695,808
# 249   2016          전국          소계       외벌이       남편만    592,468
# 250   2016          전국          소계       외벌이       아내만    103,340
# 251   2016          전국          소계        기타        소계    137,859
# 492   2017          전국          소계        합계        소계  1,379,766
# 493   2017          전국          소계       맞벌이        소계    585,957
# 494   2017          전국          소계       외벌이        소계    664,023
# 495   2017          전국          소계       외벌이       남편만    563,830
# 496   2017          전국          소계       외벌이       아내만    100,193
# 497   2017          전국          소계        기타        소계    129,786
# 738   2018          전국          소계        합계        소계  1,322,406
# 739   2018          전국          소계       맞벌이        소계    594,409
# 740   2018          전국          소계       외벌이        소계    614,246
# 741   2018          전국          소계       외벌이       남편만    519,107
# 742   2018          전국          소계       외벌이       아내만     95,139
# 743   2018          전국          소계        기타        소계    113,751
# 984   2019          전국          소계        합계        소계  1,260,117
# 985   2019          전국          소계       맞벌이        소계    582,985
# 986   2019          전국          소계       외벌이        소계    570,528
# 987   2019          전국          소계       외벌이       남편만    478,826
# 988   2019          전국          소계       외벌이       아내만     91,702
# 989   2019          전국          소계        기타        소계    106,604
# 1230  2020          전국          소계        합계        소계  1,183,750
# 1231  2020          전국          소계       맞벌이        소계    580,089
# 1232  2020          전국          소계       외벌이        소계    516,083
# 1233  2020          전국          소계       외벌이       남편만    432,127
# 1234  2020          전국          소계       외벌이       아내만     83,956
# 1235  2020          전국          소계        기타        소계     87,578
# 1476  2021          전국          소계        합계        소계  1,101,455
# 1477  2021          전국          소계       맞벌이        소계    569,472
# 1478  2021          전국          소계       외벌이        소계    457,069
# 1479  2021          전국          소계       외벌이       남편만    380,523
# 1480  2021          전국          소계       외벌이       아내만     76,546
# 1481  2021          전국          소계        기타        소계     74,914
# 1722  2022          전국          소계        합계        소계  1,032,253
# 1723  2022          전국          소계       맞벌이        소계    555,743
# 1724  2022          전국          소계       외벌이        소계    410,936
# 1725  2022          전국          소계       외벌이       남편만    341,349
# 1726  2022          전국          소계       외벌이       아내만     69,587
# 1727  2022          전국          소계        기타        소계     65,574

# %%
# 신혼부부별(1) 조건에 맞는 에서 ['전국', '시도별', '주택소유물건수별'] 만 남겨서 저장
df2 = df.loc[df["신혼부부 특성별(1)"].isin(['전국', '시도별', '주택소유물건수별']), :]
df2
# Out:
#         시점 신혼부부 특성별(1) 신혼부부 특성별(2) 맞벌이여부별(1) 맞벌이여부별(2)        데이터
# 0     2015          전국          소계        합계        소계  1,471,647
# 1     2015          전국          소계       맞벌이        소계    595,850
# 2     2015          전국          소계       외벌이        소계    735,503
# 3     2015          전국          소계       외벌이       남편만    635,596
# 4     2015          전국          소계       외벌이       아내만     99,907
# ...    ...         ...         ...       ...       ...        ...
# 1963  2022    주택소유물건수별        3건이상       맞벌이        소계      8,345
# 1964  2022    주택소유물건수별        3건이상       외벌이        소계      5,180
# 1965  2022    주택소유물건수별        3건이상       외벌이       남편만      4,056
# 1966  2022    주택소유물건수별        3건이상       외벌이       아내만      1,124
# 1967  2022    주택소유물건수별        3건이상        기타        소계        884
#
# [1104 rows x 6 columns]

# %%
df1.to_csv('맞벌이여부별_전국', index = False)

# %%
df2.to_csv('맞벌이여부별_종합', index = False)

# %% [markdown]
# # 시각화되어있는 자료열 데이터화
#     - 저출산 대응 예산 추이

# %%
col = ['연도','예산안']
data = [['2006','2.1'],['2007','2.1'],['2008','2.1'],['2009','2.1'],['2010','2.1']]

# %%
col = ['연도','예산안']
start_year = 2006
end_year = 2023
budget_value = '2.1'
data = [[str(year), budget_value] for year in range(start_year, end_year + 1)]

# 데이터프레임 생성
df = pd.DataFrame(data, columns=col)

# %%
df.예산안 = ['2.1','3.1','3.8','4.6','6.0','7.4','11.1','13.5','13.9','14.7','21.4','24.1','26.3','36.6','44.4','46.7','51.7','48.2']
df
# Out:
#       연도   예산안
# 0   2006   2.1
# 1   2007   3.1
# 2   2008   3.8
# 3   2009   4.6
# 4   2010   6.0
# 5   2011   7.4
# 6   2012  11.1
# 7   2013  13.5
# 8   2014  13.9
# 9   2015  14.7
# 10  2016  21.4
# 11  2017  24.1
# 12  2018  26.3
# 13  2019  36.6
# 14  2020  44.4
# 15  2021  46.7
# 16  2022  51.7
# 17  2023  48.2

# %%
df.to_csv('저출산대응예산추이' , index=False)

# %% [markdown]
# #데이터 볼륨 체크

# %%
df2 = pd.read_csv('/content/drive/MyDrive/5. 미드프로젝트/초혼연령.csv', encoding='cp949', header=2)
df2
# Out:
#   Unnamed: 0           2013   2014   2015   2016   2017   2018   2019   2020  \
# 0         남편          32.21  32.42  32.57  32.79  32.94  33.15  33.37  33.23
# 1         아내          29.59  29.81  29.96  30.11  30.24  30.40  30.59  30.78
# 2        출처:  통계청, 「인구동향조사」    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#     2021   2022
# 0  33.35  33.72
# 1  31.08  31.26
# 2    NaN    NaN

# %%
df2.shape
# Out:
# (3, 11)

# %%
df3 = pd.read_csv('/content/drive/MyDrive/5. 미드프로젝트/결혼에대한 인식.csv', encoding = 'cp949', header=2)
df3
# Out:
#          Unnamed: 0                                           1998   2002  \
# 0         반드시?해야?한다                                           33.6   25.6
# 1          하는?것이?좋다                                           39.9   43.5
# 2  해도?좋고,?하지?않아도?좋다                                           23.8   27.2
# 3        하지?않는것이?좋다                                            1.1    1.7
# 4         하지?말아야?한다                                            0.2    0.2
# 5            잘?모르겠다                                            1.4    1.8
# 6                합계                                          100.0  100.0
# 7               출처:                                     통계청,「사회조사」    NaN
# 8               주석:  1) 2010년까지는 15세 이상, 2012년부터 13세 이상 인구를 대상으로 함    NaN
#
#     2006   2008   2010   2012   2014   2016   2018   2020   2022
# 0   25.7   23.6   21.7   20.3   14.9   12.5   11.1   16.8   15.3
# 1   42.0   44.4   43.0   42.4   41.9   39.3   37.0   34.4   34.8
# 2   27.5   27.7   30.7   33.6   38.9   42.9   46.6   41.4   43.2
# 3    1.8    2.4    2.8    1.5    1.6    2.5    2.5    3.5    2.9
# 4    0.4    0.5    0.5    0.3    0.4    0.6    0.5    0.9    0.7
# 5    2.6    1.4    1.3    1.9    2.2    2.2    2.3    3.0    3.2
# 6  100.0  100.0  100.0  100.0  100.0  100.0  100.0  100.0  100.0
# 7    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 8    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN

# %%
df3.shape
# Out:
# (9, 12)
